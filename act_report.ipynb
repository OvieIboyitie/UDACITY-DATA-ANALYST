# %% [markdown]
# **OVIE IBOYITIE**

# %% [markdown]
# ## Analyzing, and Visualizing  WeRateDogs Dataset
#
# ### Introduction
# You've no doubt heard of We Rate Dogs by now. Either you follow the account on Twitter, or you've read
# about the "They're good dogs Brent" story, which took the Internet by storm in 2016.
# In case you didn't WeRateDogs is a Twitter account that rates people's dogs with a humorous comment
# about the dog. It was started in 2015 by college student Matt Nelson, and has received international
# media coverage both for its popularity and for the attention drawn to social media copyright law when it
# was suspended by Twitter.
# Over the course of two years, creator and curator Matt Nelson has built an empire out of being the
# internet’s go-to dog-rater. Nelson bestows rarely high ratings — on a 1-to-10 scale, almost all of his
# ratings are higher than 10 — on user-submitted pups, along with witty, ironic captions that are cute,
# hilarious, and relatable all at once.
# WeRateDogs started from humble beginnings — he claims the idea was hatched at an Applebee’s in 2015
# — and became an instant success. As of September 2022, the Twitter account has about 9.3million
# followers.
# WeRateDogs downloaded their Twitter archive and sent it to Udacity via email exclusively for us.
# Additional gathering, then assessing and cleaning was required to present this analyses and visualization.

# %% [markdown]
# ### Which Source has the most tweets
#
# The tweets were made using three sources,
# - TweetDeck
# - Twitter Web Client and
# - Twitter for iPhone
#
# 98% of the tweets were made using an iPhone, with tweets made from TweetDeck and Twitter Web Client accounting for just 2% of the tweets made

# %% [markdown]
# ![Source%20of%20tweets.png](attachment:Source%20of%20tweets.png)

# %% [markdown]
# ### What is the number of dogs per dog stage
#
# There are four different dog stages,
# - Doggo
# - Floofer
# - Pupper and
# - Puppo
# While some dogs belonged to one stage, others belonged to two different stages and some belonged to neither or rather had no stage indicated for them.
#
# Of 1447 images, only 189 had dog stage indictated for them. Excluding images with missing values for dog stage, 66.7% of the dogs are in Pupper stage, 20.1% are in the doggo stage, 7.9% in the puppo Stage

# %% [markdown]
# ![Number%20of%20dogs%20per%20stage.png](attachment:Number%20of%20dogs%20per%20stage.png)

# %% [markdown]
# ### What is the most popular non-dog type
# There 193 distinct types of non-dog images based on the first prediction. Based on Favorites counts the most popular non-dog types are
# - Bathtub
# - Seat belt
# - Prison
# - Website
#
# The image below showrs the top 10 most popular non-dog types based on Favorite counts

# %% [markdown]
# ![Most%20popular%20non-dog%20type.png](attachment:Most%20popular%20non-dog%20type.png)

# %% [markdown]
# ### What is the most popular type of dog
#
# There several types of dogs, but 110 distinct dog types based on the first prediction. Based on Favorites counts the most popular dog types are
# - Golden retriever
# - Pembroke
# - Labrador Retriever
# - Bench bulldog
#
# The image below showrs the top 20 most popular dog types based on Favorite counts

# %% [markdown]
# ![Top%2020%20most%20popular%20dog%20type.png](attachment:Top%2020%20most%20popular%20dog%20type.png)

# %% [markdown]
# ### What is relationship between number of retweets and favorite count
#
# There exists a strong linear relatoionship  between number of retweets and favorite counts. This linear relationship is qauntified by a linear correaltion of 0.73. The more an image is retweeted the higher the number of audience the image reaches and the higher the chances of the favorite count increasing.

# %% [markdown]
# ![retweet%20count%20vs%20favorite%20count.png](attachment:retweet%20count%20vs%20favorite%20count.png)
